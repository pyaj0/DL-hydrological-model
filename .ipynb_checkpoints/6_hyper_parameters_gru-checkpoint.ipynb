# %% [markdown]
# ## Imports

# %%
# import libraries
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
# import keras modules
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
# import scikit-optimize modules
import skopt
from sklearn.preprocessing import MinMaxScaler
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Integer 
from skopt.plots import plot_convergence, plot_objective, plot_evaluations, plot_histogram, plot_objective_2D 
from skopt.utils import use_named_args

# %%
# check versions of libraries
print("Tensorflow: " + tf.__version__)
print("Keras: " + tf.keras.__version__)
print("Skop: " + skopt.__version__)
# Out:
# Tensorflow: 2.4.1
# Keras: 2.4.0
# Skop: 0.8.1

# %% [markdown]
# ## Hyper parameter optimization

# %% [markdown]
# Hyperparameter optimization refers to performing a search to discover the set of specific model configuration arguments that result in the best performance of the model on a specific dataset.
#
# There are many ways to perform hyperparameter optimization, although modern methods, such as Bayesian optimization, are fast and effective. The Scikit-Optimize (skop) library is an opensource Python library that provides an implementation of Bayesian Optimization that can be used to tune the hyperparameters of machine learning models from the scikit-learn Python library. Bayesian optimization is an efficient optimization algorithm based on Bayes Theorem capable of finding the minimum or maximum of arbitrary cost functions.
#
# In our case, the goal was to minimize the cost function of the GRU model. The selected GRU network's parameters to optimize were the learning rate, the number of GRU units, the dimension of epochs and the batch size. The idea is that we have a true fitness function (the performance of a neural network on some dataset) and we want to find the minimum. To find out how the NN performs with a given set of hyperparameters, we need to train the network. A model called the Gaussain Process is built. The search starts with the initial values of the hyperparameters. At the early optimization phase, the search is explored more and in the later phase, the search is focused on the best regions found. At the end of the process, we would get a set of hyperparameters corresponding to the minimal validation loss.

# %% [markdown]
# ![Hyperparameter optimization process](./images/bayesian_optimization_gru.png)

# %%
# set hyper-parameters
# learning rate
dim_learning_rate = Real(low=1e-3, high=1, prior='log-uniform', name='learning_rate')

# number of gru layers
dim_num_gru_units = Integer(low=1, high=500, name='num_gru_units')

# number of epochs
dim_num_epochs = Integer(low=1, high=500, name='num_epochs')

# number of batch size
dim_num_batch_size = Integer(low=1, high=500, name='num_batch_size')

# %%
# combine hyper-parameters
dimensions = [dim_learning_rate, dim_num_gru_units, dim_num_epochs, dim_num_batch_size]

# %%
# set default parameter values
default_parameters = [1e-2, 100, 100, 100]

# %%
# define a helper-function for log-dir-name
def log_dir_name(learning_rate, num_gru_units,
                 num_epochs, num_batch_size):

    # the dir-name for the TensorBoard log-dir
    s = "./5_logs/lr_{0:.0e}_gru_{1}_epochs_{2}_batch_{3}/"

    # insert all the hyper-parameters in the dir-name
    log_dir = s.format(learning_rate,
                       num_gru_units,
                       num_epochs,
                       num_batch_size)

    return log_dir

# %%
# load data
df = pd.read_csv('./model_data/model_data_interpolated.csv')

# %%
# drop time column
date_time = pd.to_datetime(df.pop('Date'), format='%Y-%m-%d') #or infer_datetime_format=True

# %%
# select values of dataframe
values = df.values

# %%
# rescale data between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
# function to transform time series to supervised learning series
from pandas import DataFrame
from pandas import concat

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# using function above
reframed = series_to_supervised(scaled, 1, 1)

# %%
# drop columns we don't want to predict
reframed.drop(reframed.columns[[5,6,7,8,9,10]], axis=1, inplace=True)

# %%
# split into train, val and test sets
values = reframed.values

n_train_years = 7305 # days in 20 years for training
n_val_years = 9131 - n_train_years # days in 5 years for validating
n_val_sum = n_train_years + n_val_years

train = values[:n_train_years, :]
val = values[n_train_years:n_val_sum, :]
test = values[n_val_sum:, :]

# %%
# split into input and outputs
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = val[:, :-1], val[:, -1]
x_test, y_test = test[:, :-1], test[:, -1]

# %%
# reshape input to be 3D [samples, timesteps, features]
x_train = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
x_val = x_val.reshape((x_val.shape[0], 1, x_val.shape[1]))
x_test = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))
print(x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)
# Out:
# (7305, 1, 5) (7305,) (1826, 1, 5) (1826,) (1674, 1, 5) (1674,)

# %%
def create_model(learning_rate, num_gru_units, num_batch_size, num_epochs):
    
    """
    Hyper-parameters:
    learning_rate:     Learning-rate for the optimizer.
    num_gru_units:    Number of gru units.
    num_epochs:        Number of epochs.
    num_batch_size:    Batch size of model.
    """
                       
    model = Sequential()
    
    model.add(GRU(units=num_gru_units, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dense(units=1))

    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
    
    return model

# %%
# save network with best hyper-parameters
path_best_model = '5_best_model.h5'

# %%
# set regression loss
best_loss = float('inf')

# %%
# Define function that creates and trains a neural network with the given hyper-parameters
#and then evaluates its performance on the validation-set
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_gru_units, num_epochs, num_batch_size):
    
    """
    Hyper-parameters:
    learning_rate:     Learning-rate for the optimizer.
    num_gru_units:    Number of gru units.
    num_epochs:        Number of epochs.
    num_batch_size:    Batch size of model.
    """

    # Print the hyper-parameters.
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_gru_units:', num_gru_units)
    print('num_epochs:', num_epochs)
    print('num_batch_size:', num_batch_size)
    print()
    
    # Create the neural network with these hyper-parameters.
    model = create_model(learning_rate=learning_rate,
                         num_gru_units=num_gru_units,
                         num_epochs=num_epochs,
                         num_batch_size=num_batch_size)

    # Dir-name for the TensorBoard log-files.
    log_dir = log_dir_name(learning_rate, num_gru_units,
                           num_epochs, num_batch_size)
    
    # Create a callback-function for Keras which will be
    # run after each epoch has ended during training.
    # This saves the log-files for TensorBoard.
    # Note that there are complications when histogram_freq=1.
    # It might give strange errors and it also does not properly
    # support Keras data-generators for the validation-set.
    callback_log = TensorBoard(
        log_dir=log_dir,
        histogram_freq=0,
        write_graph=True,
        write_grads=False,
        write_images=False)
   
    # Use Keras to train the model.
    history = model.fit(x=x_train,
                        y=y_train,
                        epochs=num_epochs,
                        batch_size=num_batch_size,
                        validation_data=(x_val, y_val),
                        verbose=2, 
                        shuffle=False,
                        callbacks=[callback_log])

    # Get the loss on the validation-set
    # after the last training-epoch.
    val_loss = history.history['val_loss'][-1]

    # Print the classification accuracy.
    print()
    print("Loss: {0:.2%}".format(val_loss))
    print()

    # Save the model if it improves on the best-found performance.
    # We use the global keyword so we update the variable outside
    # of this function.
    global best_loss

    # If the loss of the saved model is improved ...
    if val_loss < best_loss:
        # Save the new model to harddisk.
        model.save(path_best_model)
        
        # Update the loss.
        best_loss = val_loss

    # Delete the Keras model with these hyper-parameters from memory.
    del model
    
    # Clear the Keras session, otherwise it will keep adding new
    # models to the same TensorFlow graph each time we create
    # a model with a different set of hyper-parameters.
    K.clear_session()
    
    # find a set of hyper-parameters with the LOWEST fitness-value
    return val_loss

# %%
# check run
fitness(x=default_parameters)
# Out:
# learning rate: 1.0e-02
# num_gru_units: 100
# num_epochs: 100
# num_batch_size: 100
#
# Epoch 1/100
# 74/74 - 4s - loss: 0.0246 - mae: 0.1104 - val_loss: 0.0096 - val_mae: 0.0769
# Epoch 2/100
# 74/74 - 0s - loss: 0.0065 - mae: 0.0570 - val_loss: 0.0091 - val_mae: 0.0693
# Epoch 3/100
# 74/74 - 0s - loss: 0.0054 - mae: 0.0508 - val_loss: 0.0099 - val_mae: 0.0739
# Epoch 4/100
# 74/74 - 0s - loss: 0.0047 - mae: 0.0467 - val_loss: 0.0102 - val_mae: 0.0752
# Epoch 5/100
# 74/74 - 0s - loss: 0.0042 - mae: 0.0438 - val_loss: 0.0101 - val_mae: 0.0748
# Epoch 6/100
# 74/74 - 0s - loss: 0.0039 - mae: 0.0422 - val_loss: 0.0098 - val_mae: 0.0737
# Epoch 7/100
# 74/74 - 0s - loss: 0.0038 - mae: 0.0412 - val_loss: 0.0095 - val_mae: 0.0724
# Epoch 8/100
# 74/74 - 0s - loss: 0.0036 - mae: 0.0405 - val_loss: 0.0092 - val_mae: 0.0711
# Epoch 9/100
# 74/74 - 0s - loss: 0.0035 - mae: 0.0400 - val_loss: 0.0090 - val_mae: 0.0698
# Epoch 10/100
# 74/74 - 0s - loss: 0.0035 - mae: 0.0397 - val_loss: 0.0087 - val_mae: 0.0685
# Epoch 11/100
# 74/74 - 0s - loss: 0.0034 - mae: 0.0393 - val_loss: 0.0084 - val_mae: 0.0673
# Epoch 12/100
# 74/74 - 0s - loss: 0.0034 - mae: 0.0391 - val_loss: 0.0082 - val_mae: 0.0662
# Epoch 13/100
# 74/74 - 0s - loss: 0.0033 - mae: 0.0388 - val_loss: 0.0080 - val_mae: 0.0651
# Epoch 14/100
# 74/74 - 0s - loss: 0.0033 - mae: 0.0386 - val_loss: 0.0078 - val_mae: 0.0640
# Epoch 15/100
# 74/74 - 0s - loss: 0.0033 - mae: 0.0383 - val_loss: 0.0075 - val_mae: 0.0629
# Epoch 16/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0381 - val_loss: 0.0073 - val_mae: 0.0618
# Epoch 17/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0380 - val_loss: 0.0071 - val_mae: 0.0607
# Epoch 18/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0378 - val_loss: 0.0069 - val_mae: 0.0596
# Epoch 19/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0376 - val_loss: 0.0067 - val_mae: 0.0585
# Epoch 20/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0375 - val_loss: 0.0065 - val_mae: 0.0574
# Epoch 21/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0373 - val_loss: 0.0063 - val_mae: 0.0563
# Epoch 22/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0372 - val_loss: 0.0061 - val_mae: 0.0552
# Epoch 23/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0371 - val_loss: 0.0059 - val_mae: 0.0541
# Epoch 24/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0369 - val_loss: 0.0058 - val_mae: 0.0530
# Epoch 25/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0368 - val_loss: 0.0056 - val_mae: 0.0519
# Epoch 26/100
# 74/74 - 1s - loss: 0.0031 - mae: 0.0367 - val_loss: 0.0054 - val_mae: 0.0508
# Epoch 27/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0365 - val_loss: 0.0053 - val_mae: 0.0499
# Epoch 28/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0364 - val_loss: 0.0052 - val_mae: 0.0491
# Epoch 29/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0363 - val_loss: 0.0051 - val_mae: 0.0484
# Epoch 30/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0361 - val_loss: 0.0050 - val_mae: 0.0478
# Epoch 31/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0360 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 32/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0359 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 33/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0358 - val_loss: 0.0047 - val_mae: 0.0462
# Epoch 34/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0356 - val_loss: 0.0047 - val_mae: 0.0459
# Epoch 35/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0355 - val_loss: 0.0046 - val_mae: 0.0457
# Epoch 36/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0354 - val_loss: 0.0046 - val_mae: 0.0456
# Epoch 37/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0352 - val_loss: 0.0045 - val_mae: 0.0456
# Epoch 38/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0351 - val_loss: 0.0045 - val_mae: 0.0455
# Epoch 39/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0350 - val_loss: 0.0045 - val_mae: 0.0456
# Epoch 40/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0349 - val_loss: 0.0045 - val_mae: 0.0456
# Epoch 41/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0348 - val_loss: 0.0044 - val_mae: 0.0456
# Epoch 42/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0347 - val_loss: 0.0044 - val_mae: 0.0456
# Epoch 43/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0346 - val_loss: 0.0044 - val_mae: 0.0457
# Epoch 44/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0345 - val_loss: 0.0044 - val_mae: 0.0457
# Epoch 45/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0344 - val_loss: 0.0044 - val_mae: 0.0457
# Epoch 46/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0343 - val_loss: 0.0044 - val_mae: 0.0458
# Epoch 47/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0342 - val_loss: 0.0044 - val_mae: 0.0458
# Epoch 48/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0341 - val_loss: 0.0044 - val_mae: 0.0459
# Epoch 49/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0341 - val_loss: 0.0044 - val_mae: 0.0459
# Epoch 50/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0340 - val_loss: 0.0044 - val_mae: 0.0460
# Epoch 51/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0339 - val_loss: 0.0044 - val_mae: 0.0460
# Epoch 52/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0339 - val_loss: 0.0044 - val_mae: 0.0460
# Epoch 53/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0338 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 54/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0338 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 55/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0337 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 56/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0337 - val_loss: 0.0043 - val_mae: 0.0461
# Epoch 57/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0336 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 58/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0336 - val_loss: 0.0043 - val_mae: 0.0461
# Epoch 59/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 60/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 61/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 62/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 63/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0334 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 64/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0333 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 65/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0332 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 66/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0332 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 67/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0331 - val_loss: 0.0043 - val_mae: 0.0458
# Epoch 68/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0331 - val_loss: 0.0043 - val_mae: 0.0458
# Epoch 69/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0331 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 70/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0330 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 71/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0330 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 72/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0329 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 73/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0329 - val_loss: 0.0042 - val_mae: 0.0457
# Epoch 74/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0328 - val_loss: 0.0042 - val_mae: 0.0456
# Epoch 75/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0328 - val_loss: 0.0042 - val_mae: 0.0456
# Epoch 76/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0327 - val_loss: 0.0042 - val_mae: 0.0455
# Epoch 77/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0327 - val_loss: 0.0042 - val_mae: 0.0455
# Epoch 78/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0327 - val_loss: 0.0042 - val_mae: 0.0454
# Epoch 79/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0326 - val_loss: 0.0042 - val_mae: 0.0454
# Epoch 80/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0326 - val_loss: 0.0042 - val_mae: 0.0453
# Epoch 81/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0325 - val_loss: 0.0042 - val_mae: 0.0453
# Epoch 82/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0325 - val_loss: 0.0042 - val_mae: 0.0453
# Epoch 83/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0324 - val_loss: 0.0042 - val_mae: 0.0452
# Epoch 84/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0324 - val_loss: 0.0042 - val_mae: 0.0451
# Epoch 85/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0324 - val_loss: 0.0042 - val_mae: 0.0451
# Epoch 86/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0323 - val_loss: 0.0042 - val_mae: 0.0450
# Epoch 87/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0323 - val_loss: 0.0042 - val_mae: 0.0450
# Epoch 88/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0322 - val_loss: 0.0042 - val_mae: 0.0450
# Epoch 89/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0322 - val_loss: 0.0041 - val_mae: 0.0449
# Epoch 90/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0041 - val_mae: 0.0448
# Epoch 91/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0041 - val_mae: 0.0448
# Epoch 92/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0041 - val_mae: 0.0448
# Epoch 93/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0320 - val_loss: 0.0041 - val_mae: 0.0447
# Epoch 94/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0320 - val_loss: 0.0041 - val_mae: 0.0446
# Epoch 95/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0041 - val_mae: 0.0445
# Epoch 96/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0041 - val_mae: 0.0445
# Epoch 97/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0041 - val_mae: 0.0445
# Epoch 98/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0318 - val_loss: 0.0041 - val_mae: 0.0444
# Epoch 99/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0318 - val_loss: 0.0041 - val_mae: 0.0444
# Epoch 100/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0318 - val_loss: 0.0041 - val_mae: 0.0443
#
# Loss: 0.41%
# 0.0040855808183550835

# %%
##### run the hyper-parameter optimization
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='EI',
                            n_calls=40,
                            x0=default_parameters)
# Out:
# learning rate: 1.0e-02
# num_gru_units: 100
# num_epochs: 100
# num_batch_size: 100
#
# Epoch 1/100
# 74/74 - 5s - loss: 0.0254 - mae: 0.1142 - val_loss: 0.0098 - val_mae: 0.0754
# Epoch 2/100
# 74/74 - 1s - loss: 0.0069 - mae: 0.0591 - val_loss: 0.0087 - val_mae: 0.0671
# Epoch 3/100
# 74/74 - 0s - loss: 0.0055 - mae: 0.0514 - val_loss: 0.0093 - val_mae: 0.0704
# Epoch 4/100
# 74/74 - 0s - loss: 0.0047 - mae: 0.0466 - val_loss: 0.0097 - val_mae: 0.0727
# Epoch 5/100
# 74/74 - 0s - loss: 0.0042 - mae: 0.0436 - val_loss: 0.0097 - val_mae: 0.0732
# Epoch 6/100
# 74/74 - 0s - loss: 0.0039 - mae: 0.0420 - val_loss: 0.0096 - val_mae: 0.0728
# Epoch 7/100
# 74/74 - 0s - loss: 0.0037 - mae: 0.0410 - val_loss: 0.0094 - val_mae: 0.0721
# Epoch 8/100
# 74/74 - 0s - loss: 0.0036 - mae: 0.0404 - val_loss: 0.0092 - val_mae: 0.0713
# Epoch 9/100
# 74/74 - 0s - loss: 0.0035 - mae: 0.0400 - val_loss: 0.0090 - val_mae: 0.0704
# Epoch 10/100
# 74/74 - 0s - loss: 0.0034 - mae: 0.0397 - val_loss: 0.0088 - val_mae: 0.0696
# Epoch 11/100
# 74/74 - 0s - loss: 0.0034 - mae: 0.0394 - val_loss: 0.0087 - val_mae: 0.0688
# Epoch 12/100
# 74/74 - 0s - loss: 0.0033 - mae: 0.0392 - val_loss: 0.0085 - val_mae: 0.0680
# Epoch 13/100
# 74/74 - 0s - loss: 0.0033 - mae: 0.0390 - val_loss: 0.0084 - val_mae: 0.0673
# Epoch 14/100
# 74/74 - 0s - loss: 0.0033 - mae: 0.0387 - val_loss: 0.0082 - val_mae: 0.0666
# Epoch 15/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0385 - val_loss: 0.0081 - val_mae: 0.0659
# Epoch 16/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0383 - val_loss: 0.0079 - val_mae: 0.0652
# Epoch 17/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0382 - val_loss: 0.0078 - val_mae: 0.0646
# Epoch 18/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0380 - val_loss: 0.0077 - val_mae: 0.0639
# Epoch 19/100
# 74/74 - 0s - loss: 0.0032 - mae: 0.0379 - val_loss: 0.0075 - val_mae: 0.0631
# Epoch 20/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0377 - val_loss: 0.0074 - val_mae: 0.0622
# Epoch 21/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0376 - val_loss: 0.0072 - val_mae: 0.0614
# Epoch 22/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0375 - val_loss: 0.0070 - val_mae: 0.0606
# Epoch 23/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0374 - val_loss: 0.0069 - val_mae: 0.0597
# Epoch 24/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0373 - val_loss: 0.0067 - val_mae: 0.0587
# Epoch 25/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0372 - val_loss: 0.0065 - val_mae: 0.0578
# Epoch 26/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0371 - val_loss: 0.0064 - val_mae: 0.0568
# Epoch 27/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0371 - val_loss: 0.0061 - val_mae: 0.0555
# Epoch 28/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0370 - val_loss: 0.0059 - val_mae: 0.0542
# Epoch 29/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0369 - val_loss: 0.0057 - val_mae: 0.0530
# Epoch 30/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0368 - val_loss: 0.0056 - val_mae: 0.0520
# Epoch 31/100
# 74/74 - 0s - loss: 0.0031 - mae: 0.0367 - val_loss: 0.0055 - val_mae: 0.0510
# Epoch 32/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0366 - val_loss: 0.0053 - val_mae: 0.0499
# Epoch 33/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0365 - val_loss: 0.0051 - val_mae: 0.0489
# Epoch 34/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0364 - val_loss: 0.0050 - val_mae: 0.0479
# Epoch 35/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0363 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 36/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0362 - val_loss: 0.0048 - val_mae: 0.0464
# Epoch 37/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0360 - val_loss: 0.0047 - val_mae: 0.0459
# Epoch 38/100
# 74/74 - 0s - loss: 0.0030 - mae: 0.0358 - val_loss: 0.0046 - val_mae: 0.0455
# Epoch 39/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0356 - val_loss: 0.0045 - val_mae: 0.0453
# Epoch 40/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0355 - val_loss: 0.0045 - val_mae: 0.0452
# Epoch 41/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0353 - val_loss: 0.0045 - val_mae: 0.0452
# Epoch 42/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0352 - val_loss: 0.0044 - val_mae: 0.0452
# Epoch 43/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0351 - val_loss: 0.0044 - val_mae: 0.0452
# Epoch 44/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0349 - val_loss: 0.0044 - val_mae: 0.0453
# Epoch 45/100
# 74/74 - 0s - loss: 0.0029 - mae: 0.0348 - val_loss: 0.0044 - val_mae: 0.0454
# Epoch 46/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0347 - val_loss: 0.0044 - val_mae: 0.0454
# Epoch 47/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0346 - val_loss: 0.0044 - val_mae: 0.0455
# Epoch 48/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0345 - val_loss: 0.0044 - val_mae: 0.0456
# Epoch 49/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0344 - val_loss: 0.0043 - val_mae: 0.0456
# Epoch 50/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0343 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 51/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0342 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 52/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0341 - val_loss: 0.0043 - val_mae: 0.0458
# Epoch 53/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0340 - val_loss: 0.0043 - val_mae: 0.0458
# Epoch 54/100
# 74/74 - 0s - loss: 0.0028 - mae: 0.0340 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 55/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0339 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 56/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0339 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 57/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0338 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 58/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0338 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 59/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0337 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 60/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0337 - val_loss: 0.0043 - val_mae: 0.0460
# Epoch 61/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0336 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 62/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0336 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 63/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0336 - val_loss: 0.0043 - val_mae: 0.0459
# Epoch 64/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0336 - val_loss: 0.0043 - val_mae: 0.0458
# Epoch 65/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 66/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 67/100
# 74/74 - 0s - loss: 0.0027 - mae: 0.0335 - val_loss: 0.0043 - val_mae: 0.0457
# Epoch 68/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0334 - val_loss: 0.0043 - val_mae: 0.0456
# Epoch 69/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0334 - val_loss: 0.0043 - val_mae: 0.0455
# Epoch 70/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0334 - val_loss: 0.0043 - val_mae: 0.0455
# Epoch 71/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0333 - val_loss: 0.0043 - val_mae: 0.0455
# Epoch 72/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0332 - val_loss: 0.0043 - val_mae: 0.0454
# Epoch 73/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0332 - val_loss: 0.0042 - val_mae: 0.0454
# Epoch 74/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0331 - val_loss: 0.0042 - val_mae: 0.0453
# Epoch 75/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0331 - val_loss: 0.0042 - val_mae: 0.0452
# Epoch 76/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0331 - val_loss: 0.0042 - val_mae: 0.0452
# Epoch 77/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0330 - val_loss: 0.0042 - val_mae: 0.0451
# Epoch 78/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0330 - val_loss: 0.0042 - val_mae: 0.0450
# Epoch 79/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0329 - val_loss: 0.0042 - val_mae: 0.0450
# Epoch 80/100
# 74/74 - 0s - loss: 0.0026 - mae: 0.0329 - val_loss: 0.0042 - val_mae: 0.0449
# Epoch 81/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0328 - val_loss: 0.0042 - val_mae: 0.0449
# Epoch 82/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0328 - val_loss: 0.0042 - val_mae: 0.0448
# Epoch 83/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0327 - val_loss: 0.0042 - val_mae: 0.0447
# Epoch 84/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0327 - val_loss: 0.0042 - val_mae: 0.0447
# Epoch 85/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0326 - val_loss: 0.0042 - val_mae: 0.0446
# Epoch 86/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0326 - val_loss: 0.0042 - val_mae: 0.0445
# Epoch 87/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0325 - val_loss: 0.0042 - val_mae: 0.0445
# Epoch 88/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0325 - val_loss: 0.0042 - val_mae: 0.0444
# Epoch 89/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0324 - val_loss: 0.0041 - val_mae: 0.0443
# Epoch 90/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0324 - val_loss: 0.0041 - val_mae: 0.0442
# Epoch 91/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0323 - val_loss: 0.0041 - val_mae: 0.0442
# Epoch 92/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0323 - val_loss: 0.0041 - val_mae: 0.0441
# Epoch 93/100
# 74/74 - 0s - loss: 0.0025 - mae: 0.0322 - val_loss: 0.0041 - val_mae: 0.0440
# Epoch 94/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0041 - val_mae: 0.0440
# Epoch 95/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0321 - val_loss: 0.0041 - val_mae: 0.0439
# Epoch 96/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0320 - val_loss: 0.0041 - val_mae: 0.0438
# Epoch 97/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0320 - val_loss: 0.0041 - val_mae: 0.0438
# Epoch 98/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0041 - val_mae: 0.0437
# Epoch 99/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0319 - val_loss: 0.0041 - val_mae: 0.0436
# Epoch 100/100
# 74/74 - 0s - loss: 0.0024 - mae: 0.0318 - val_loss: 0.0041 - val_mae: 0.0436
#
# Loss: 0.41%
#
# learning rate: 2.2e-03
# num_gru_units: 405
# num_epochs: 45
# num_batch_size: 203
#
# Epoch 1/45
# 36/36 - 6s - loss: 0.0323 - mae: 0.1235 - val_loss: 0.0177 - val_mae: 0.0994
# Epoch 2/45
# 36/36 - 1s - loss: 0.0054 - mae: 0.0511 - val_loss: 0.0104 - val_mae: 0.0707
# Epoch 3/45
# 36/36 - 1s - loss: 0.0045 - mae: 0.0461 - val_loss: 0.0083 - val_mae: 0.0613
# Epoch 4/45
# 36/36 - 1s - loss: 0.0041 - mae: 0.0443 - val_loss: 0.0067 - val_mae: 0.0544
# Epoch 5/45
# 36/36 - 1s - loss: 0.0038 - mae: 0.0425 - val_loss: 0.0060 - val_mae: 0.0518
# Epoch 6/45
# 36/36 - 1s - loss: 0.0035 - mae: 0.0408 - val_loss: 0.0057 - val_mae: 0.0510
# Epoch 7/45
# 36/36 - 1s - loss: 0.0034 - mae: 0.0399 - val_loss: 0.0055 - val_mae: 0.0511
# Epoch 8/45
# 36/36 - 1s - loss: 0.0034 - mae: 0.0396 - val_loss: 0.0055 - val_mae: 0.0513
# Epoch 9/45
# 36/36 - 1s - loss: 0.0033 - mae: 0.0394 - val_loss: 0.0054 - val_mae: 0.0513
# Epoch 10/45
# 36/36 - 1s - loss: 0.0033 - mae: 0.0393 - val_loss: 0.0054 - val_mae: 0.0512
# Epoch 11/45
# 36/36 - 1s - loss: 0.0032 - mae: 0.0391 - val_loss: 0.0053 - val_mae: 0.0510
# Epoch 12/45
# 36/36 - 1s - loss: 0.0032 - mae: 0.0389 - val_loss: 0.0053 - val_mae: 0.0508
# Epoch 13/45
# 36/36 - 1s - loss: 0.0032 - mae: 0.0386 - val_loss: 0.0053 - val_mae: 0.0505
# Epoch 14/45
# 36/36 - 1s - loss: 0.0031 - mae: 0.0384 - val_loss: 0.0052 - val_mae: 0.0502
# Epoch 15/45
# 36/36 - 1s - loss: 0.0031 - mae: 0.0381 - val_loss: 0.0052 - val_mae: 0.0500
# Epoch 16/45
# 36/36 - 1s - loss: 0.0030 - mae: 0.0379 - val_loss: 0.0052 - val_mae: 0.0497
# Epoch 17/45
# 36/36 - 1s - loss: 0.0030 - mae: 0.0376 - val_loss: 0.0051 - val_mae: 0.0494
# Epoch 18/45
# 36/36 - 1s - loss: 0.0030 - mae: 0.0374 - val_loss: 0.0051 - val_mae: 0.0491
# Epoch 19/45
# 36/36 - 1s - loss: 0.0029 - mae: 0.0372 - val_loss: 0.0051 - val_mae: 0.0489
# Epoch 20/45
# 36/36 - 1s - loss: 0.0029 - mae: 0.0369 - val_loss: 0.0051 - val_mae: 0.0486
# Epoch 21/45
# 36/36 - 1s - loss: 0.0029 - mae: 0.0367 - val_loss: 0.0050 - val_mae: 0.0484
# Epoch 22/45
# 36/36 - 1s - loss: 0.0029 - mae: 0.0365 - val_loss: 0.0050 - val_mae: 0.0481
# Epoch 23/45
# 36/36 - 1s - loss: 0.0028 - mae: 0.0363 - val_loss: 0.0050 - val_mae: 0.0479
# Epoch 24/45
# 36/36 - 1s - loss: 0.0028 - mae: 0.0361 - val_loss: 0.0050 - val_mae: 0.0477
# Epoch 25/45
# 36/36 - 1s - loss: 0.0028 - mae: 0.0359 - val_loss: 0.0049 - val_mae: 0.0475
# Epoch 26/45
# 36/36 - 1s - loss: 0.0027 - mae: 0.0357 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 27/45
# 36/36 - 1s - loss: 0.0027 - mae: 0.0355 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 28/45
# 36/36 - 1s - loss: 0.0027 - mae: 0.0353 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 29/45
# 36/36 - 1s - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0049 - val_mae: 0.0466
# Epoch 30/45
# 36/36 - 1s - loss: 0.0026 - mae: 0.0349 - val_loss: 0.0049 - val_mae: 0.0464
# Epoch 31/45
# 36/36 - 1s - loss: 0.0026 - mae: 0.0347 - val_loss: 0.0048 - val_mae: 0.0462
# Epoch 32/45
# 36/36 - 1s - loss: 0.0026 - mae: 0.0346 - val_loss: 0.0048 - val_mae: 0.0461
# Epoch 33/45
# 36/36 - 1s - loss: 0.0026 - mae: 0.0344 - val_loss: 0.0048 - val_mae: 0.0459
# Epoch 34/45
# 36/36 - 1s - loss: 0.0026 - mae: 0.0342 - val_loss: 0.0048 - val_mae: 0.0457
# Epoch 35/45
# 36/36 - 1s - loss: 0.0025 - mae: 0.0341 - val_loss: 0.0048 - val_mae: 0.0456
# Epoch 36/45
# 36/36 - 1s - loss: 0.0025 - mae: 0.0339 - val_loss: 0.0048 - val_mae: 0.0454
# Epoch 37/45
# 36/36 - 1s - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0047 - val_mae: 0.0453
# Epoch 38/45
# 36/36 - 1s - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0047 - val_mae: 0.0451
# Epoch 39/45
# 36/36 - 1s - loss: 0.0025 - mae: 0.0335 - val_loss: 0.0047 - val_mae: 0.0450
# Epoch 40/45
# 36/36 - 1s - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0047 - val_mae: 0.0449
# Epoch 41/45
# 36/36 - 1s - loss: 0.0024 - mae: 0.0333 - val_loss: 0.0047 - val_mae: 0.0448
# Epoch 42/45
# 36/36 - 1s - loss: 0.0024 - mae: 0.0331 - val_loss: 0.0047 - val_mae: 0.0447
# Epoch 43/45
# 36/36 - 1s - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0047 - val_mae: 0.0446
# Epoch 44/45
# 36/36 - 1s - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0047 - val_mae: 0.0445
# Epoch 45/45
# 36/36 - 1s - loss: 0.0024 - mae: 0.0328 - val_loss: 0.0047 - val_mae: 0.0444
#
# Loss: 0.47%
#
# learning rate: 2.6e-01
# num_gru_units: 320
# num_epochs: 208
# num_batch_size: 248
#
# Epoch 1/208
# 30/30 - 4s - loss: 38.1009 - mae: 2.7111 - val_loss: 0.2683 - val_mae: 0.4333
# Epoch 2/208
# 30/30 - 1s - loss: 0.1711 - mae: 0.3347 - val_loss: 0.0614 - val_mae: 0.2097
# Epoch 3/208
# 30/30 - 1s - loss: 0.0583 - mae: 0.1910 - val_loss: 0.0318 - val_mae: 0.1416
# Epoch 4/208
# 30/30 - 1s - loss: 0.0364 - mae: 0.1499 - val_loss: 0.0248 - val_mae: 0.1208
# Epoch 5/208
# 30/30 - 1s - loss: 0.0305 - mae: 0.1368 - val_loss: 0.0230 - val_mae: 0.1130
# Epoch 6/208
# 30/30 - 1s - loss: 0.0264 - mae: 0.1265 - val_loss: 0.0217 - val_mae: 0.1092
# Epoch 7/208
# 30/30 - 1s - loss: 0.0222 - mae: 0.1158 - val_loss: 0.0208 - val_mae: 0.1073
# Epoch 8/208
# 30/30 - 1s - loss: 0.0186 - mae: 0.1061 - val_loss: 0.0204 - val_mae: 0.1073
# Epoch 9/208
# 30/30 - 1s - loss: 0.0158 - mae: 0.0979 - val_loss: 0.0203 - val_mae: 0.1082
# Epoch 10/208
# 30/30 - 1s - loss: 0.0137 - mae: 0.0910 - val_loss: 0.0202 - val_mae: 0.1087
# Epoch 11/208
# 30/30 - 1s - loss: 0.0120 - mae: 0.0853 - val_loss: 0.0199 - val_mae: 0.1082
# Epoch 12/208
# 30/30 - 1s - loss: 0.0106 - mae: 0.0801 - val_loss: 0.0193 - val_mae: 0.1066
# Epoch 13/208
# 30/30 - 1s - loss: 0.0096 - mae: 0.0756 - val_loss: 0.0184 - val_mae: 0.1040
# Epoch 14/208
# 30/30 - 1s - loss: 0.0087 - mae: 0.0715 - val_loss: 0.0173 - val_mae: 0.1005
# Epoch 15/208
# 30/30 - 1s - loss: 0.0079 - mae: 0.0680 - val_loss: 0.0161 - val_mae: 0.0966
# Epoch 16/208
# 30/30 - 1s - loss: 0.0073 - mae: 0.0648 - val_loss: 0.0149 - val_mae: 0.0926
# Epoch 17/208
# 30/30 - 1s - loss: 0.0068 - mae: 0.0620 - val_loss: 0.0137 - val_mae: 0.0887
# Epoch 18/208
# 30/30 - 1s - loss: 0.0063 - mae: 0.0593 - val_loss: 0.0127 - val_mae: 0.0848
# Epoch 19/208
# 30/30 - 1s - loss: 0.0058 - mae: 0.0568 - val_loss: 0.0117 - val_mae: 0.0809
# Epoch 20/208
# 30/30 - 1s - loss: 0.0054 - mae: 0.0544 - val_loss: 0.0108 - val_mae: 0.0772
# Epoch 21/208
# 30/30 - 1s - loss: 0.0050 - mae: 0.0521 - val_loss: 0.0100 - val_mae: 0.0735
# Epoch 22/208
# 30/30 - 1s - loss: 0.0046 - mae: 0.0498 - val_loss: 0.0092 - val_mae: 0.0700
# Epoch 23/208
# 30/30 - 1s - loss: 0.0042 - mae: 0.0477 - val_loss: 0.0086 - val_mae: 0.0666
# Epoch 24/208
# 30/30 - 1s - loss: 0.0039 - mae: 0.0457 - val_loss: 0.0080 - val_mae: 0.0636
# Epoch 25/208
# 30/30 - 1s - loss: 0.0036 - mae: 0.0438 - val_loss: 0.0076 - val_mae: 0.0610
# Epoch 26/208
# 30/30 - 1s - loss: 0.0034 - mae: 0.0421 - val_loss: 0.0072 - val_mae: 0.0586
# Epoch 27/208
# 30/30 - 1s - loss: 0.0032 - mae: 0.0406 - val_loss: 0.0068 - val_mae: 0.0566
# Epoch 28/208
# 30/30 - 1s - loss: 0.0030 - mae: 0.0393 - val_loss: 0.0065 - val_mae: 0.0548
# Epoch 29/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0383 - val_loss: 0.0062 - val_mae: 0.0531
# Epoch 30/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0376 - val_loss: 0.0060 - val_mae: 0.0516
# Epoch 31/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0370 - val_loss: 0.0057 - val_mae: 0.0502
# Epoch 32/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0366 - val_loss: 0.0055 - val_mae: 0.0488
# Epoch 33/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0363 - val_loss: 0.0053 - val_mae: 0.0475
# Epoch 34/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0360 - val_loss: 0.0051 - val_mae: 0.0463
# Epoch 35/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0357 - val_loss: 0.0049 - val_mae: 0.0454
# Epoch 36/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0354 - val_loss: 0.0048 - val_mae: 0.0448
# Epoch 37/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0350 - val_loss: 0.0047 - val_mae: 0.0443
# Epoch 38/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0345 - val_loss: 0.0046 - val_mae: 0.0440
# Epoch 39/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0341 - val_loss: 0.0045 - val_mae: 0.0437
# Epoch 40/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0337 - val_loss: 0.0045 - val_mae: 0.0435
# Epoch 41/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0333 - val_loss: 0.0045 - val_mae: 0.0432
# Epoch 42/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0044 - val_mae: 0.0431
# Epoch 43/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0044 - val_mae: 0.0429
# Epoch 44/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0324 - val_loss: 0.0044 - val_mae: 0.0427
# Epoch 45/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0044 - val_mae: 0.0426
# Epoch 46/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0044 - val_mae: 0.0425
# Epoch 47/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0044 - val_mae: 0.0424
# Epoch 48/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0043 - val_mae: 0.0423
# Epoch 49/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0043 - val_mae: 0.0422
# Epoch 50/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0043 - val_mae: 0.0421
# Epoch 51/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0420
# Epoch 52/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0419
# Epoch 53/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0419
# Epoch 54/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0418
# Epoch 55/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0417
# Epoch 56/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0417
# Epoch 57/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0314 - val_loss: 0.0043 - val_mae: 0.0416
# Epoch 58/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0043 - val_mae: 0.0416
# Epoch 59/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0315 - val_loss: 0.0043 - val_mae: 0.0415
# Epoch 60/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0316 - val_loss: 0.0043 - val_mae: 0.0415
# Epoch 61/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0043 - val_mae: 0.0415
# Epoch 62/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0043 - val_mae: 0.0415
# Epoch 63/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0043 - val_mae: 0.0415
# Epoch 64/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0319 - val_loss: 0.0042 - val_mae: 0.0415
# Epoch 65/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0042 - val_mae: 0.0415
# Epoch 66/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0322 - val_loss: 0.0042 - val_mae: 0.0415
# Epoch 67/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0042 - val_mae: 0.0416
# Epoch 68/208
# 30/30 - 1s - loss: 0.0023 - mae: 0.0324 - val_loss: 0.0042 - val_mae: 0.0417
# Epoch 69/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0042 - val_mae: 0.0418
# Epoch 70/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0042 - val_mae: 0.0419
# Epoch 71/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0328 - val_loss: 0.0042 - val_mae: 0.0420
# Epoch 72/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0042 - val_mae: 0.0421
# Epoch 73/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0331 - val_loss: 0.0042 - val_mae: 0.0423
# Epoch 74/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0332 - val_loss: 0.0042 - val_mae: 0.0425
# Epoch 75/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0334 - val_loss: 0.0042 - val_mae: 0.0427
# Epoch 76/208
# 30/30 - 1s - loss: 0.0024 - mae: 0.0335 - val_loss: 0.0042 - val_mae: 0.0429
# Epoch 77/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0337 - val_loss: 0.0042 - val_mae: 0.0432
# Epoch 78/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0043 - val_mae: 0.0434
# Epoch 79/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0339 - val_loss: 0.0043 - val_mae: 0.0437
# Epoch 80/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0341 - val_loss: 0.0043 - val_mae: 0.0439
# Epoch 81/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0342 - val_loss: 0.0043 - val_mae: 0.0442
# Epoch 82/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0343 - val_loss: 0.0043 - val_mae: 0.0445
# Epoch 83/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0345 - val_loss: 0.0043 - val_mae: 0.0448
# Epoch 84/208
# 30/30 - 1s - loss: 0.0025 - mae: 0.0346 - val_loss: 0.0044 - val_mae: 0.0451
# Epoch 85/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0347 - val_loss: 0.0044 - val_mae: 0.0455
# Epoch 86/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0349 - val_loss: 0.0044 - val_mae: 0.0458
# Epoch 87/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0350 - val_loss: 0.0044 - val_mae: 0.0462
# Epoch 88/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0351 - val_loss: 0.0044 - val_mae: 0.0465
# Epoch 89/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0352 - val_loss: 0.0045 - val_mae: 0.0469
# Epoch 90/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0354 - val_loss: 0.0045 - val_mae: 0.0472
# Epoch 91/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0355 - val_loss: 0.0045 - val_mae: 0.0476
# Epoch 92/208
# 30/30 - 1s - loss: 0.0026 - mae: 0.0356 - val_loss: 0.0046 - val_mae: 0.0480
# Epoch 93/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0357 - val_loss: 0.0046 - val_mae: 0.0484
# Epoch 94/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0358 - val_loss: 0.0046 - val_mae: 0.0488
# Epoch 95/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0360 - val_loss: 0.0046 - val_mae: 0.0492
# Epoch 96/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0361 - val_loss: 0.0047 - val_mae: 0.0495
# Epoch 97/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0362 - val_loss: 0.0047 - val_mae: 0.0499
# Epoch 98/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0363 - val_loss: 0.0047 - val_mae: 0.0503
# Epoch 99/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0364 - val_loss: 0.0048 - val_mae: 0.0507
# Epoch 100/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0365 - val_loss: 0.0048 - val_mae: 0.0511
# Epoch 101/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0366 - val_loss: 0.0048 - val_mae: 0.0515
# Epoch 102/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0367 - val_loss: 0.0049 - val_mae: 0.0519
# Epoch 103/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0368 - val_loss: 0.0049 - val_mae: 0.0523
# Epoch 104/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0369 - val_loss: 0.0049 - val_mae: 0.0527
# Epoch 105/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0369 - val_loss: 0.0050 - val_mae: 0.0531
# Epoch 106/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0370 - val_loss: 0.0050 - val_mae: 0.0534
# Epoch 107/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0371 - val_loss: 0.0050 - val_mae: 0.0538
# Epoch 108/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0371 - val_loss: 0.0051 - val_mae: 0.0541
# Epoch 109/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0372 - val_loss: 0.0051 - val_mae: 0.0544
# Epoch 110/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0372 - val_loss: 0.0051 - val_mae: 0.0547
# Epoch 111/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0550
# Epoch 112/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0552
# Epoch 113/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0554
# Epoch 114/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0556
# Epoch 115/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0558
# Epoch 116/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0373 - val_loss: 0.0052 - val_mae: 0.0559
# Epoch 117/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0372 - val_loss: 0.0053 - val_mae: 0.0559
# Epoch 118/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0372 - val_loss: 0.0053 - val_mae: 0.0560
# Epoch 119/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0371 - val_loss: 0.0052 - val_mae: 0.0559
# Epoch 120/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0370 - val_loss: 0.0052 - val_mae: 0.0558
# Epoch 121/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0369 - val_loss: 0.0052 - val_mae: 0.0557
# Epoch 122/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0368 - val_loss: 0.0052 - val_mae: 0.0555
# Epoch 123/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0366 - val_loss: 0.0052 - val_mae: 0.0552
# Epoch 124/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0365 - val_loss: 0.0051 - val_mae: 0.0549
# Epoch 125/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0363 - val_loss: 0.0051 - val_mae: 0.0546
# Epoch 126/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0361 - val_loss: 0.0050 - val_mae: 0.0541
# Epoch 127/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0359 - val_loss: 0.0050 - val_mae: 0.0537
# Epoch 128/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0357 - val_loss: 0.0049 - val_mae: 0.0532
# Epoch 129/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0355 - val_loss: 0.0049 - val_mae: 0.0526
# Epoch 130/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0353 - val_loss: 0.0048 - val_mae: 0.0521
# Epoch 131/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0048 - val_mae: 0.0515
# Epoch 132/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0350 - val_loss: 0.0047 - val_mae: 0.0510
# Epoch 133/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0348 - val_loss: 0.0047 - val_mae: 0.0505
# Epoch 134/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0046 - val_mae: 0.0500
# Epoch 135/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0346 - val_loss: 0.0046 - val_mae: 0.0495
# Epoch 136/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0345 - val_loss: 0.0046 - val_mae: 0.0491
# Epoch 137/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0344 - val_loss: 0.0045 - val_mae: 0.0487
# Epoch 138/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0344 - val_loss: 0.0045 - val_mae: 0.0483
# Epoch 139/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0343 - val_loss: 0.0045 - val_mae: 0.0480
# Epoch 140/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0344 - val_loss: 0.0045 - val_mae: 0.0478
# Epoch 141/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0344 - val_loss: 0.0044 - val_mae: 0.0475
# Epoch 142/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0344 - val_loss: 0.0044 - val_mae: 0.0474
# Epoch 143/208
# 30/30 - 0s - loss: 0.0027 - mae: 0.0345 - val_loss: 0.0044 - val_mae: 0.0472
# Epoch 144/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0346 - val_loss: 0.0044 - val_mae: 0.0471
# Epoch 145/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0044 - val_mae: 0.0470
# Epoch 146/208
# 30/30 - 1s - loss: 0.0027 - mae: 0.0349 - val_loss: 0.0044 - val_mae: 0.0470
# Epoch 147/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0350 - val_loss: 0.0044 - val_mae: 0.0470
# Epoch 148/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0352 - val_loss: 0.0044 - val_mae: 0.0469
# Epoch 149/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0354 - val_loss: 0.0044 - val_mae: 0.0469
# Epoch 150/208
# 30/30 - 2s - loss: 0.0028 - mae: 0.0356 - val_loss: 0.0044 - val_mae: 0.0470
# Epoch 151/208
# 30/30 - 1s - loss: 0.0028 - mae: 0.0358 - val_loss: 0.0045 - val_mae: 0.0470
# Epoch 152/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0360 - val_loss: 0.0045 - val_mae: 0.0470
# Epoch 153/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0362 - val_loss: 0.0045 - val_mae: 0.0471
# Epoch 154/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0365 - val_loss: 0.0045 - val_mae: 0.0472
# Epoch 155/208
# 30/30 - 1s - loss: 0.0029 - mae: 0.0367 - val_loss: 0.0045 - val_mae: 0.0472
# Epoch 156/208
# 30/30 - 1s - loss: 0.0030 - mae: 0.0370 - val_loss: 0.0045 - val_mae: 0.0473
# Epoch 157/208
# 30/30 - 1s - loss: 0.0030 - mae: 0.0373 - val_loss: 0.0045 - val_mae: 0.0473
# Epoch 158/208
# 30/30 - 1s - loss: 0.0030 - mae: 0.0375 - val_loss: 0.0045 - val_mae: 0.0474
# Epoch 159/208
# 30/30 - 1s - loss: 0.0030 - mae: 0.0378 - val_loss: 0.0045 - val_mae: 0.0475
# Epoch 160/208
# 30/30 - 1s - loss: 0.0031 - mae: 0.0381 - val_loss: 0.0046 - val_mae: 0.0475
# Epoch 161/208
# 30/30 - 1s - loss: 0.0031 - mae: 0.0384 - val_loss: 0.0046 - val_mae: 0.0476
# Epoch 162/208
# 30/30 - 1s - loss: 0.0031 - mae: 0.0387 - val_loss: 0.0046 - val_mae: 0.0477
# Epoch 163/208
# 30/30 - 1s - loss: 0.0032 - mae: 0.0390 - val_loss: 0.0046 - val_mae: 0.0477
# Epoch 164/208
# 30/30 - 1s - loss: 0.0032 - mae: 0.0393 - val_loss: 0.0046 - val_mae: 0.0478
# Epoch 165/208
# 30/30 - 1s - loss: 0.0032 - mae: 0.0396 - val_loss: 0.0046 - val_mae: 0.0479
# Epoch 166/208
# 30/30 - 1s - loss: 0.0033 - mae: 0.0399 - val_loss: 0.0046 - val_mae: 0.0479
# Epoch 167/208
# 30/30 - 1s - loss: 0.0033 - mae: 0.0402 - val_loss: 0.0046 - val_mae: 0.0480
# Epoch 168/208
# 30/30 - 1s - loss: 0.0033 - mae: 0.0405 - val_loss: 0.0047 - val_mae: 0.0481
# Epoch 169/208
# 30/30 - 1s - loss: 0.0034 - mae: 0.0408 - val_loss: 0.0047 - val_mae: 0.0481
# Epoch 170/208
# 30/30 - 1s - loss: 0.0034 - mae: 0.0411 - val_loss: 0.0047 - val_mae: 0.0482
# Epoch 171/208
# 30/30 - 1s - loss: 0.0034 - mae: 0.0414 - val_loss: 0.0047 - val_mae: 0.0483
# Epoch 172/208
# 30/30 - 1s - loss: 0.0035 - mae: 0.0416 - val_loss: 0.0047 - val_mae: 0.0484
# Epoch 173/208
# 30/30 - 1s - loss: 0.0035 - mae: 0.0419 - val_loss: 0.0047 - val_mae: 0.0485
# Epoch 174/208
# 30/30 - 1s - loss: 0.0035 - mae: 0.0422 - val_loss: 0.0047 - val_mae: 0.0486
# Epoch 175/208
# 30/30 - 1s - loss: 0.0035 - mae: 0.0425 - val_loss: 0.0047 - val_mae: 0.0487
# Epoch 176/208
# 30/30 - 1s - loss: 0.0036 - mae: 0.0427 - val_loss: 0.0048 - val_mae: 0.0488
# Epoch 177/208
# 30/30 - 1s - loss: 0.0036 - mae: 0.0430 - val_loss: 0.0048 - val_mae: 0.0489
# Epoch 178/208
# 30/30 - 1s - loss: 0.0036 - mae: 0.0432 - val_loss: 0.0048 - val_mae: 0.0490
# Epoch 179/208
# 30/30 - 1s - loss: 0.0037 - mae: 0.0435 - val_loss: 0.0048 - val_mae: 0.0491
# Epoch 180/208
# 30/30 - 1s - loss: 0.0037 - mae: 0.0438 - val_loss: 0.0048 - val_mae: 0.0493
# Epoch 181/208
# 30/30 - 1s - loss: 0.0037 - mae: 0.0440 - val_loss: 0.0048 - val_mae: 0.0494
# Epoch 182/208
# 30/30 - 1s - loss: 0.0037 - mae: 0.0443 - val_loss: 0.0049 - val_mae: 0.0496
# Epoch 183/208
# 30/30 - 1s - loss: 0.0038 - mae: 0.0445 - val_loss: 0.0049 - val_mae: 0.0497
# Epoch 184/208
# 30/30 - 1s - loss: 0.0038 - mae: 0.0447 - val_loss: 0.0049 - val_mae: 0.0499
# Epoch 185/208
# 30/30 - 1s - loss: 0.0038 - mae: 0.0450 - val_loss: 0.0049 - val_mae: 0.0500
# Epoch 186/208
# 30/30 - 1s - loss: 0.0038 - mae: 0.0452 - val_loss: 0.0049 - val_mae: 0.0502
# Epoch 187/208
# 30/30 - 1s - loss: 0.0039 - mae: 0.0455 - val_loss: 0.0050 - val_mae: 0.0504
# Epoch 188/208
# 30/30 - 1s - loss: 0.0039 - mae: 0.0457 - val_loss: 0.0050 - val_mae: 0.0506
# Epoch 189/208
# 30/30 - 1s - loss: 0.0039 - mae: 0.0460 - val_loss: 0.0050 - val_mae: 0.0508
# Epoch 190/208
# 30/30 - 1s - loss: 0.0039 - mae: 0.0462 - val_loss: 0.0050 - val_mae: 0.0510
# Epoch 191/208
# 30/30 - 1s - loss: 0.0040 - mae: 0.0464 - val_loss: 0.0050 - val_mae: 0.0512
# Epoch 192/208
# 30/30 - 1s - loss: 0.0040 - mae: 0.0467 - val_loss: 0.0051 - val_mae: 0.0514
# Epoch 193/208
# 30/30 - 1s - loss: 0.0040 - mae: 0.0469 - val_loss: 0.0051 - val_mae: 0.0517
# Epoch 194/208
# 30/30 - 1s - loss: 0.0040 - mae: 0.0471 - val_loss: 0.0051 - val_mae: 0.0519
# Epoch 195/208
# 30/30 - 1s - loss: 0.0041 - mae: 0.0473 - val_loss: 0.0052 - val_mae: 0.0522
# Epoch 196/208
# 30/30 - 1s - loss: 0.0041 - mae: 0.0475 - val_loss: 0.0052 - val_mae: 0.0525
# Epoch 197/208
# 30/30 - 1s - loss: 0.0041 - mae: 0.0477 - val_loss: 0.0052 - val_mae: 0.0528
# Epoch 198/208
# 30/30 - 1s - loss: 0.0041 - mae: 0.0479 - val_loss: 0.0053 - val_mae: 0.0530
# Epoch 199/208
# 30/30 - 1s - loss: 0.0041 - mae: 0.0481 - val_loss: 0.0053 - val_mae: 0.0533
# Epoch 200/208
# 30/30 - 1s - loss: 0.0042 - mae: 0.0483 - val_loss: 0.0053 - val_mae: 0.0536
# Epoch 201/208
# 30/30 - 1s - loss: 0.0042 - mae: 0.0485 - val_loss: 0.0054 - val_mae: 0.0539
# Epoch 202/208
# 30/30 - 1s - loss: 0.0042 - mae: 0.0487 - val_loss: 0.0054 - val_mae: 0.0541
# Epoch 203/208
# 30/30 - 1s - loss: 0.0042 - mae: 0.0489 - val_loss: 0.0055 - val_mae: 0.0544
# Epoch 204/208
# 30/30 - 1s - loss: 0.0042 - mae: 0.0491 - val_loss: 0.0055 - val_mae: 0.0546
# Epoch 205/208
# 30/30 - 1s - loss: 0.0043 - mae: 0.0493 - val_loss: 0.0055 - val_mae: 0.0549
# Epoch 206/208
# 30/30 - 1s - loss: 0.0043 - mae: 0.0495 - val_loss: 0.0055 - val_mae: 0.0551
# Epoch 207/208
# 30/30 - 1s - loss: 0.0043 - mae: 0.0496 - val_loss: 0.0056 - val_mae: 0.0553
# Epoch 208/208
# 30/30 - 1s - loss: 0.0043 - mae: 0.0498 - val_loss: 0.0056 - val_mae: 0.0555
#
# Loss: 0.56%
#
# learning rate: 3.3e-01
# num_gru_units: 434
# num_epochs: 348
# num_batch_size: 110
#
# Epoch 1/348
# 67/67 - 5s - loss: 73.7059 - mae: 2.6173 - val_loss: 0.0479 - val_mae: 0.1813
# Epoch 2/348
# 67/67 - 1s - loss: 0.0547 - mae: 0.1783 - val_loss: 0.0321 - val_mae: 0.1337
# Epoch 3/348
# 67/67 - 1s - loss: 0.0384 - mae: 0.1462 - val_loss: 0.0299 - val_mae: 0.1312
# Epoch 4/348
# 67/67 - 1s - loss: 0.0311 - mae: 0.1315 - val_loss: 0.0293 - val_mae: 0.1341
# Epoch 5/348
# 67/67 - 1s - loss: 0.0265 - mae: 0.1225 - val_loss: 0.0285 - val_mae: 0.1344
# Epoch 6/348
# 67/67 - 1s - loss: 0.0231 - mae: 0.1153 - val_loss: 0.0272 - val_mae: 0.1322
# Epoch 7/348
# 67/67 - 1s - loss: 0.0205 - mae: 0.1090 - val_loss: 0.0257 - val_mae: 0.1286
# Epoch 8/348
# 67/67 - 1s - loss: 0.0183 - mae: 0.1032 - val_loss: 0.0241 - val_mae: 0.1243
# Epoch 9/348
# 67/67 - 1s - loss: 0.0165 - mae: 0.0978 - val_loss: 0.0225 - val_mae: 0.1198
# Epoch 10/348
# 67/67 - 1s - loss: 0.0149 - mae: 0.0929 - val_loss: 0.0210 - val_mae: 0.1153
# Epoch 11/348
# 67/67 - 1s - loss: 0.0136 - mae: 0.0882 - val_loss: 0.0197 - val_mae: 0.1108
# Epoch 12/348
# 67/67 - 1s - loss: 0.0124 - mae: 0.0837 - val_loss: 0.0183 - val_mae: 0.1061
# Epoch 13/348
# 67/67 - 1s - loss: 0.0113 - mae: 0.0792 - val_loss: 0.0169 - val_mae: 0.1010
# Epoch 14/348
# 67/67 - 1s - loss: 0.0103 - mae: 0.0748 - val_loss: 0.0155 - val_mae: 0.0956
# Epoch 15/348
# 67/67 - 1s - loss: 0.0094 - mae: 0.0709 - val_loss: 0.0141 - val_mae: 0.0904
# Epoch 16/348
# 67/67 - 1s - loss: 0.0087 - mae: 0.0676 - val_loss: 0.0129 - val_mae: 0.0859
# Epoch 17/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0650 - val_loss: 0.0119 - val_mae: 0.0820
# Epoch 18/348
# 67/67 - 1s - loss: 0.0075 - mae: 0.0628 - val_loss: 0.0111 - val_mae: 0.0789
# Epoch 19/348
# 67/67 - 1s - loss: 0.0070 - mae: 0.0609 - val_loss: 0.0104 - val_mae: 0.0768
# Epoch 20/348
# 67/67 - 1s - loss: 0.0066 - mae: 0.0590 - val_loss: 0.0098 - val_mae: 0.0752
# Epoch 21/348
# 67/67 - 1s - loss: 0.0062 - mae: 0.0570 - val_loss: 0.0093 - val_mae: 0.0739
# Epoch 22/348
# 67/67 - 1s - loss: 0.0058 - mae: 0.0551 - val_loss: 0.0088 - val_mae: 0.0723
# Epoch 23/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0533 - val_loss: 0.0083 - val_mae: 0.0704
# Epoch 24/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0517 - val_loss: 0.0078 - val_mae: 0.0685
# Epoch 25/348
# 67/67 - 1s - loss: 0.0049 - mae: 0.0503 - val_loss: 0.0074 - val_mae: 0.0668
# Epoch 26/348
# 67/67 - 1s - loss: 0.0047 - mae: 0.0491 - val_loss: 0.0070 - val_mae: 0.0651
# Epoch 27/348
# 67/67 - 1s - loss: 0.0046 - mae: 0.0481 - val_loss: 0.0067 - val_mae: 0.0634
# Epoch 28/348
# 67/67 - 1s - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0064 - val_mae: 0.0615
# Epoch 29/348
# 67/67 - 1s - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0061 - val_mae: 0.0594
# Epoch 30/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0465 - val_loss: 0.0059 - val_mae: 0.0572
# Epoch 31/348
# 67/67 - 1s - loss: 0.0041 - mae: 0.0460 - val_loss: 0.0058 - val_mae: 0.0551
# Epoch 32/348
# 67/67 - 1s - loss: 0.0040 - mae: 0.0455 - val_loss: 0.0058 - val_mae: 0.0533
# Epoch 33/348
# 67/67 - 1s - loss: 0.0039 - mae: 0.0450 - val_loss: 0.0059 - val_mae: 0.0522
# Epoch 34/348
# 67/67 - 1s - loss: 0.0038 - mae: 0.0444 - val_loss: 0.0062 - val_mae: 0.0519
# Epoch 35/348
# 67/67 - 1s - loss: 0.0037 - mae: 0.0438 - val_loss: 0.0065 - val_mae: 0.0529
# Epoch 36/348
# 67/67 - 1s - loss: 0.0036 - mae: 0.0431 - val_loss: 0.0069 - val_mae: 0.0553
# Epoch 37/348
# 67/67 - 1s - loss: 0.0035 - mae: 0.0426 - val_loss: 0.0074 - val_mae: 0.0586
# Epoch 38/348
# 67/67 - 1s - loss: 0.0035 - mae: 0.0422 - val_loss: 0.0079 - val_mae: 0.0627
# Epoch 39/348
# 67/67 - 1s - loss: 0.0035 - mae: 0.0420 - val_loss: 0.0085 - val_mae: 0.0671
# Epoch 40/348
# 67/67 - 1s - loss: 0.0035 - mae: 0.0420 - val_loss: 0.0092 - val_mae: 0.0717
# Epoch 41/348
# 67/67 - 1s - loss: 0.0035 - mae: 0.0421 - val_loss: 0.0099 - val_mae: 0.0763
# Epoch 42/348
# 67/67 - 1s - loss: 0.0035 - mae: 0.0423 - val_loss: 0.0106 - val_mae: 0.0808
# Epoch 43/348
# 67/67 - 1s - loss: 0.0036 - mae: 0.0426 - val_loss: 0.0114 - val_mae: 0.0852
# Epoch 44/348
# 67/67 - 1s - loss: 0.0036 - mae: 0.0430 - val_loss: 0.0122 - val_mae: 0.0893
# Epoch 45/348
# 67/67 - 1s - loss: 0.0037 - mae: 0.0434 - val_loss: 0.0129 - val_mae: 0.0930
# Epoch 46/348
# 67/67 - 1s - loss: 0.0037 - mae: 0.0437 - val_loss: 0.0135 - val_mae: 0.0964
# Epoch 47/348
# 67/67 - 1s - loss: 0.0037 - mae: 0.0442 - val_loss: 0.0142 - val_mae: 0.0993
# Epoch 48/348
# 67/67 - 1s - loss: 0.0038 - mae: 0.0448 - val_loss: 0.0147 - val_mae: 0.1020
# Epoch 49/348
# 67/67 - 1s - loss: 0.0039 - mae: 0.0455 - val_loss: 0.0153 - val_mae: 0.1045
# Epoch 50/348
# 67/67 - 1s - loss: 0.0039 - mae: 0.0463 - val_loss: 0.0158 - val_mae: 0.1069
# Epoch 51/348
# 67/67 - 1s - loss: 0.0041 - mae: 0.0472 - val_loss: 0.0163 - val_mae: 0.1092
# Epoch 52/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0482 - val_loss: 0.0169 - val_mae: 0.1116
# Epoch 53/348
# 67/67 - 1s - loss: 0.0043 - mae: 0.0493 - val_loss: 0.0174 - val_mae: 0.1139
# Epoch 54/348
# 67/67 - 1s - loss: 0.0045 - mae: 0.0505 - val_loss: 0.0180 - val_mae: 0.1161
# Epoch 55/348
# 67/67 - 1s - loss: 0.0046 - mae: 0.0518 - val_loss: 0.0185 - val_mae: 0.1182
# Epoch 56/348
# 67/67 - 1s - loss: 0.0048 - mae: 0.0531 - val_loss: 0.0190 - val_mae: 0.1201
# Epoch 57/348
# 67/67 - 1s - loss: 0.0050 - mae: 0.0544 - val_loss: 0.0194 - val_mae: 0.1217
# Epoch 58/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0558 - val_loss: 0.0198 - val_mae: 0.1231
# Epoch 59/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0571 - val_loss: 0.0201 - val_mae: 0.1242
# Epoch 60/348
# 67/67 - 1s - loss: 0.0056 - mae: 0.0585 - val_loss: 0.0202 - val_mae: 0.1249
# Epoch 61/348
# 67/67 - 1s - loss: 0.0058 - mae: 0.0599 - val_loss: 0.0203 - val_mae: 0.1252
# Epoch 62/348
# 67/67 - 1s - loss: 0.0060 - mae: 0.0612 - val_loss: 0.0203 - val_mae: 0.1252
# Epoch 63/348
# 67/67 - 1s - loss: 0.0062 - mae: 0.0624 - val_loss: 0.0202 - val_mae: 0.1249
# Epoch 64/348
# 67/67 - 1s - loss: 0.0064 - mae: 0.0636 - val_loss: 0.0200 - val_mae: 0.1242
# Epoch 65/348
# 67/67 - 1s - loss: 0.0065 - mae: 0.0647 - val_loss: 0.0197 - val_mae: 0.1232
# Epoch 66/348
# 67/67 - 1s - loss: 0.0067 - mae: 0.0658 - val_loss: 0.0194 - val_mae: 0.1220
# Epoch 67/348
# 67/67 - 1s - loss: 0.0069 - mae: 0.0667 - val_loss: 0.0191 - val_mae: 0.1206
# Epoch 68/348
# 67/67 - 1s - loss: 0.0071 - mae: 0.0677 - val_loss: 0.0187 - val_mae: 0.1193
# Epoch 69/348
# 67/67 - 1s - loss: 0.0073 - mae: 0.0686 - val_loss: 0.0184 - val_mae: 0.1181
# Epoch 70/348
# 67/67 - 1s - loss: 0.0075 - mae: 0.0696 - val_loss: 0.0183 - val_mae: 0.1174
# Epoch 71/348
# 67/67 - 1s - loss: 0.0077 - mae: 0.0706 - val_loss: 0.0183 - val_mae: 0.1174
# Epoch 72/348
# 67/67 - 1s - loss: 0.0079 - mae: 0.0718 - val_loss: 0.0186 - val_mae: 0.1183
# Epoch 73/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0730 - val_loss: 0.0193 - val_mae: 0.1202
# Epoch 74/348
# 67/67 - 1s - loss: 0.0083 - mae: 0.0739 - val_loss: 0.0200 - val_mae: 0.1224
# Epoch 75/348
# 67/67 - 1s - loss: 0.0084 - mae: 0.0742 - val_loss: 0.0206 - val_mae: 0.1237
# Epoch 76/348
# 67/67 - 1s - loss: 0.0084 - mae: 0.0738 - val_loss: 0.0208 - val_mae: 0.1236
# Epoch 77/348
# 67/67 - 1s - loss: 0.0083 - mae: 0.0732 - val_loss: 0.0208 - val_mae: 0.1227
# Epoch 78/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0728 - val_loss: 0.0207 - val_mae: 0.1217
# Epoch 79/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0727 - val_loss: 0.0205 - val_mae: 0.1206
# Epoch 80/348
# 67/67 - 1s - loss: 0.0080 - mae: 0.0728 - val_loss: 0.0202 - val_mae: 0.1194
# Epoch 81/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0732 - val_loss: 0.0198 - val_mae: 0.1182
# Epoch 82/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0736 - val_loss: 0.0193 - val_mae: 0.1164
# Epoch 83/348
# 67/67 - 1s - loss: 0.0082 - mae: 0.0739 - val_loss: 0.0185 - val_mae: 0.1136
# Epoch 84/348
# 67/67 - 1s - loss: 0.0082 - mae: 0.0739 - val_loss: 0.0175 - val_mae: 0.1096
# Epoch 85/348
# 67/67 - 1s - loss: 0.0081 - mae: 0.0737 - val_loss: 0.0163 - val_mae: 0.1045
# Epoch 86/348
# 67/67 - 2s - loss: 0.0080 - mae: 0.0731 - val_loss: 0.0149 - val_mae: 0.0983
# Epoch 87/348
# 67/67 - 1s - loss: 0.0079 - mae: 0.0721 - val_loss: 0.0134 - val_mae: 0.0910
# Epoch 88/348
# 67/67 - 1s - loss: 0.0077 - mae: 0.0708 - val_loss: 0.0119 - val_mae: 0.0831
# Epoch 89/348
# 67/67 - 1s - loss: 0.0074 - mae: 0.0690 - val_loss: 0.0105 - val_mae: 0.0750
# Epoch 90/348
# 67/67 - 1s - loss: 0.0070 - mae: 0.0669 - val_loss: 0.0091 - val_mae: 0.0674
# Epoch 91/348
# 67/67 - 1s - loss: 0.0066 - mae: 0.0645 - val_loss: 0.0080 - val_mae: 0.0612
# Epoch 92/348
# 67/67 - 1s - loss: 0.0061 - mae: 0.0620 - val_loss: 0.0071 - val_mae: 0.0571
# Epoch 93/348
# 67/67 - 1s - loss: 0.0057 - mae: 0.0593 - val_loss: 0.0064 - val_mae: 0.0544
# Epoch 94/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0566 - val_loss: 0.0059 - val_mae: 0.0527
# Epoch 95/348
# 67/67 - 2s - loss: 0.0049 - mae: 0.0541 - val_loss: 0.0056 - val_mae: 0.0520
# Epoch 96/348
# 67/67 - 2s - loss: 0.0046 - mae: 0.0519 - val_loss: 0.0054 - val_mae: 0.0518
# Epoch 97/348
# 67/67 - 1s - loss: 0.0044 - mae: 0.0501 - val_loss: 0.0053 - val_mae: 0.0519
# Epoch 98/348
# 67/67 - 2s - loss: 0.0042 - mae: 0.0488 - val_loss: 0.0052 - val_mae: 0.0521
# Epoch 99/348
# 67/67 - 2s - loss: 0.0041 - mae: 0.0479 - val_loss: 0.0052 - val_mae: 0.0524
# Epoch 100/348
# 67/67 - 2s - loss: 0.0040 - mae: 0.0474 - val_loss: 0.0052 - val_mae: 0.0527
# Epoch 101/348
# 67/67 - 2s - loss: 0.0040 - mae: 0.0471 - val_loss: 0.0052 - val_mae: 0.0529
# Epoch 102/348
# 67/67 - 1s - loss: 0.0039 - mae: 0.0469 - val_loss: 0.0052 - val_mae: 0.0533
# Epoch 103/348
# 67/67 - 2s - loss: 0.0040 - mae: 0.0469 - val_loss: 0.0053 - val_mae: 0.0537
# Epoch 104/348
# 67/67 - 2s - loss: 0.0040 - mae: 0.0470 - val_loss: 0.0053 - val_mae: 0.0542
# Epoch 105/348
# 67/67 - 2s - loss: 0.0040 - mae: 0.0473 - val_loss: 0.0053 - val_mae: 0.0548
# Epoch 106/348
# 67/67 - 2s - loss: 0.0041 - mae: 0.0476 - val_loss: 0.0054 - val_mae: 0.0554
# Epoch 107/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0480 - val_loss: 0.0054 - val_mae: 0.0561
# Epoch 108/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0484 - val_loss: 0.0054 - val_mae: 0.0566
# Epoch 109/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0486 - val_loss: 0.0055 - val_mae: 0.0569
# Epoch 110/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0487 - val_loss: 0.0054 - val_mae: 0.0569
# Epoch 111/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0485 - val_loss: 0.0054 - val_mae: 0.0566
# Epoch 112/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0481 - val_loss: 0.0053 - val_mae: 0.0560
# Epoch 113/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0477 - val_loss: 0.0052 - val_mae: 0.0553
# Epoch 114/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0473 - val_loss: 0.0052 - val_mae: 0.0547
# Epoch 115/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0469 - val_loss: 0.0051 - val_mae: 0.0541
# Epoch 116/348
# 67/67 - 1s - loss: 0.0042 - mae: 0.0467 - val_loss: 0.0050 - val_mae: 0.0533
# Epoch 117/348
# 67/67 - 1s - loss: 0.0043 - mae: 0.0467 - val_loss: 0.0050 - val_mae: 0.0524
# Epoch 118/348
# 67/67 - 1s - loss: 0.0043 - mae: 0.0469 - val_loss: 0.0049 - val_mae: 0.0517
# Epoch 119/348
# 67/67 - 1s - loss: 0.0044 - mae: 0.0474 - val_loss: 0.0049 - val_mae: 0.0511
# Epoch 120/348
# 67/67 - 1s - loss: 0.0046 - mae: 0.0481 - val_loss: 0.0048 - val_mae: 0.0501
# Epoch 121/348
# 67/67 - 1s - loss: 0.0047 - mae: 0.0488 - val_loss: 0.0048 - val_mae: 0.0504
# Epoch 122/348
# 67/67 - 1s - loss: 0.0050 - mae: 0.0507 - val_loss: 0.0046 - val_mae: 0.0479
# Epoch 123/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0520 - val_loss: 0.0047 - val_mae: 0.0502
# Epoch 124/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0518 - val_loss: 0.0047 - val_mae: 0.0484
# Epoch 125/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0514 - val_loss: 0.0050 - val_mae: 0.0527
# Epoch 126/348
# 67/67 - 1s - loss: 0.0055 - mae: 0.0537 - val_loss: 0.0047 - val_mae: 0.0484
# Epoch 127/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0523 - val_loss: 0.0047 - val_mae: 0.0495
# Epoch 128/348
# 67/67 - 1s - loss: 0.0053 - mae: 0.0523 - val_loss: 0.0047 - val_mae: 0.0477
# Epoch 129/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0517 - val_loss: 0.0050 - val_mae: 0.0515
# Epoch 130/348
# 67/67 - 1s - loss: 0.0056 - mae: 0.0548 - val_loss: 0.0048 - val_mae: 0.0483
# Epoch 131/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0519 - val_loss: 0.0049 - val_mae: 0.0500
# Epoch 132/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0537 - val_loss: 0.0048 - val_mae: 0.0483
# Epoch 133/348
# 67/67 - 1s - loss: 0.0053 - mae: 0.0527 - val_loss: 0.0048 - val_mae: 0.0485
# Epoch 134/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0535 - val_loss: 0.0048 - val_mae: 0.0483
# Epoch 135/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0524 - val_loss: 0.0049 - val_mae: 0.0491
# Epoch 136/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0530 - val_loss: 0.0049 - val_mae: 0.0489
# Epoch 137/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0526 - val_loss: 0.0050 - val_mae: 0.0493
# Epoch 138/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0546 - val_loss: 0.0050 - val_mae: 0.0493
# Epoch 139/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0522 - val_loss: 0.0051 - val_mae: 0.0494
# Epoch 140/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0525 - val_loss: 0.0052 - val_mae: 0.0483
# Epoch 141/348
# 67/67 - 1s - loss: 0.0049 - mae: 0.0511 - val_loss: 0.0055 - val_mae: 0.0502
# Epoch 142/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0525 - val_loss: 0.0062 - val_mae: 0.0533
# Epoch 143/348
# 67/67 - 1s - loss: 0.0056 - mae: 0.0549 - val_loss: 0.0064 - val_mae: 0.0550
# Epoch 144/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0536 - val_loss: 0.0051 - val_mae: 0.0507
# Epoch 145/348
# 67/67 - 2s - loss: 0.0050 - mae: 0.0513 - val_loss: 0.0053 - val_mae: 0.0492
# Epoch 146/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0511 - val_loss: 0.0052 - val_mae: 0.0497
# Epoch 147/348
# 67/67 - 1s - loss: 0.0051 - mae: 0.0515 - val_loss: 0.0047 - val_mae: 0.0471
# Epoch 148/348
# 67/67 - 1s - loss: 0.0055 - mae: 0.0554 - val_loss: 0.0052 - val_mae: 0.0489
# Epoch 149/348
# 67/67 - 1s - loss: 0.0050 - mae: 0.0509 - val_loss: 0.0050 - val_mae: 0.0481
# Epoch 150/348
# 67/67 - 2s - loss: 0.0054 - mae: 0.0541 - val_loss: 0.0051 - val_mae: 0.0479
# Epoch 151/348
# 67/67 - 1s - loss: 0.0049 - mae: 0.0500 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 152/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0527 - val_loss: 0.0054 - val_mae: 0.0484
# Epoch 153/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0531 - val_loss: 0.0053 - val_mae: 0.0483
# Epoch 154/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0530 - val_loss: 0.0055 - val_mae: 0.0484
# Epoch 155/348
# 67/67 - 1s - loss: 0.0052 - mae: 0.0518 - val_loss: 0.0045 - val_mae: 0.0446
# Epoch 156/348
# 67/67 - 2s - loss: 0.0053 - mae: 0.0527 - val_loss: 0.0050 - val_mae: 0.0459
# Epoch 157/348
# 67/67 - 1s - loss: 0.0049 - mae: 0.0498 - val_loss: 0.0049 - val_mae: 0.0456
# Epoch 158/348
# 67/67 - 1s - loss: 0.0057 - mae: 0.0558 - val_loss: 0.0051 - val_mae: 0.0470
# Epoch 159/348
# 67/67 - 2s - loss: 0.0051 - mae: 0.0516 - val_loss: 0.0079 - val_mae: 0.0670
# Epoch 160/348
# 67/67 - 2s - loss: 0.0054 - mae: 0.0542 - val_loss: 0.0070 - val_mae: 0.0618
# Epoch 161/348
# 67/67 - 2s - loss: 0.0053 - mae: 0.0534 - val_loss: 0.0052 - val_mae: 0.0474
# Epoch 162/348
# 67/67 - 2s - loss: 0.0054 - mae: 0.0542 - val_loss: 0.0068 - val_mae: 0.0588
# Epoch 163/348
# 67/67 - 2s - loss: 0.0053 - mae: 0.0534 - val_loss: 0.0075 - val_mae: 0.0646
# Epoch 164/348
# 67/67 - 1s - loss: 0.0054 - mae: 0.0542 - val_loss: 0.0077 - val_mae: 0.0659
# Epoch 165/348
# 67/67 - 1s - loss: 0.0055 - mae: 0.0546 - val_loss: 0.0067 - val_mae: 0.0597
# Epoch 166/348
# 67/67 - 1s - loss: 0.0056 - mae: 0.0551 - val_loss: 0.0057 - val_mae: 0.0492
# Epoch 167/348
# 67/67 - 1s - loss: 0.0053 - mae: 0.0536 - val_loss: 0.0075 - val_mae: 0.0626
# Epoch 168/348
# 67/67 - 1s - loss: 0.0055 - mae: 0.0544 - val_loss: 0.0073 - val_mae: 0.0616
# Epoch 169/348
# 67/67 - 2s - loss: 0.0056 - mae: 0.0552 - val_loss: 0.0092 - val_mae: 0.0740
# Epoch 170/348
# 67/67 - 2s - loss: 0.0056 - mae: 0.0546 - val_loss: 0.0099 - val_mae: 0.0772
# Epoch 171/348
# 67/67 - 2s - loss: 0.0059 - mae: 0.0568 - val_loss: 0.0112 - val_mae: 0.0835
# Epoch 172/348
# 67/67 - 2s - loss: 0.0063 - mae: 0.0582 - val_loss: 0.0118 - val_mae: 0.0861
# Epoch 173/348
# 67/67 - 2s - loss: 0.0064 - mae: 0.0588 - val_loss: 0.0081 - val_mae: 0.0675
# Epoch 174/348
# 67/67 - 2s - loss: 0.0062 - mae: 0.0582 - val_loss: 0.0147 - val_mae: 0.0965
# Epoch 175/348
# 67/67 - 2s - loss: 0.0078 - mae: 0.0653 - val_loss: 0.0163 - val_mae: 0.1035
# Epoch 176/348
# ...
# Epoch 56/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0326 - val_loss: 0.0053 - val_mae: 0.0468
# Epoch 57/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0325 - val_loss: 0.0053 - val_mae: 0.0468
# Epoch 58/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0325 - val_loss: 0.0053 - val_mae: 0.0468
# Epoch 59/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0324 - val_loss: 0.0053 - val_mae: 0.0468
# Epoch 60/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0324 - val_loss: 0.0053 - val_mae: 0.0468
# Epoch 61/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 62/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0323 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 63/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0322 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 64/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0322 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 65/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0322 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 66/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 67/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 68/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 69/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 70/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 71/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 72/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 73/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 74/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 75/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 76/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 77/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 78/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 79/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 80/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 81/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 82/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 83/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 84/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 85/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 86/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 87/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 88/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 89/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 90/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 91/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 92/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 93/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 94/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 95/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 96/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 97/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 98/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 99/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 100/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 101/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 102/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 103/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 104/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 105/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0466
# Epoch 106/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0470
# Epoch 107/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 108/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 109/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 110/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 111/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 112/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 113/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 114/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 115/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 116/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 117/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0466
# Epoch 118/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 119/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0053 - val_mae: 0.0464
# Epoch 120/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0053 - val_mae: 0.0465
# Epoch 121/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 122/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 123/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0466
# Epoch 124/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0465
# Epoch 125/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0465
# Epoch 126/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0465
# Epoch 127/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0465
# Epoch 128/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0465
# Epoch 129/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0466
# Epoch 130/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 131/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0466
# Epoch 132/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 133/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0466
# Epoch 134/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0054 - val_mae: 0.0466
# Epoch 135/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 136/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 137/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 138/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 139/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0467
# Epoch 140/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0316 - val_loss: 0.0054 - val_mae: 0.0468
# Epoch 141/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0054 - val_mae: 0.0468
# Epoch 142/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0054 - val_mae: 0.0469
# Epoch 143/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0054 - val_mae: 0.0468
# Epoch 144/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0054 - val_mae: 0.0470
# Epoch 145/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0054 - val_mae: 0.0469
# Epoch 146/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0054 - val_mae: 0.0470
# Epoch 147/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0055 - val_mae: 0.0471
# Epoch 148/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0055 - val_mae: 0.0471
# Epoch 149/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0055 - val_mae: 0.0472
# Epoch 150/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0055 - val_mae: 0.0473
# Epoch 151/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0055 - val_mae: 0.0472
# Epoch 152/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0055 - val_mae: 0.0473
# Epoch 153/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0055 - val_mae: 0.0474
# Epoch 154/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0055 - val_mae: 0.0473
# Epoch 155/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0055 - val_mae: 0.0473
# Epoch 156/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0055 - val_mae: 0.0474
# Epoch 157/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0055 - val_mae: 0.0475
# Epoch 158/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0056 - val_mae: 0.0476
# Epoch 159/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0056 - val_mae: 0.0478
# Epoch 160/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0322 - val_loss: 0.0056 - val_mae: 0.0478
# Epoch 161/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0323 - val_loss: 0.0056 - val_mae: 0.0478
# Epoch 162/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0323 - val_loss: 0.0056 - val_mae: 0.0478
# Epoch 163/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0323 - val_loss: 0.0056 - val_mae: 0.0483
# Epoch 164/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0324 - val_loss: 0.0057 - val_mae: 0.0482
# Epoch 165/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0324 - val_loss: 0.0056 - val_mae: 0.0481
# Epoch 166/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0325 - val_loss: 0.0057 - val_mae: 0.0483
# Epoch 167/231
# 17/17 - 0s - loss: 0.0022 - mae: 0.0325 - val_loss: 0.0057 - val_mae: 0.0486
# Epoch 168/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0327 - val_loss: 0.0057 - val_mae: 0.0485
# Epoch 169/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0326 - val_loss: 0.0057 - val_mae: 0.0485
# Epoch 170/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0327 - val_loss: 0.0057 - val_mae: 0.0490
# Epoch 171/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0328 - val_loss: 0.0058 - val_mae: 0.0489
# Epoch 172/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0328 - val_loss: 0.0058 - val_mae: 0.0491
# Epoch 173/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0328 - val_loss: 0.0059 - val_mae: 0.0496
# Epoch 174/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0059 - val_mae: 0.0500
# Epoch 175/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0059 - val_mae: 0.0497
# Epoch 176/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0332 - val_loss: 0.0059 - val_mae: 0.0503
# Epoch 177/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0333 - val_loss: 0.0060 - val_mae: 0.0503
# Epoch 178/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0334 - val_loss: 0.0060 - val_mae: 0.0506
# Epoch 179/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0335 - val_loss: 0.0060 - val_mae: 0.0504
# Epoch 180/231
# 17/17 - 0s - loss: 0.0023 - mae: 0.0334 - val_loss: 0.0061 - val_mae: 0.0511
# Epoch 181/231
# 17/17 - 0s - loss: 0.0024 - mae: 0.0337 - val_loss: 0.0061 - val_mae: 0.0510
# Epoch 182/231
# 17/17 - 0s - loss: 0.0024 - mae: 0.0336 - val_loss: 0.0060 - val_mae: 0.0509
# Epoch 183/231
# 17/17 - 0s - loss: 0.0024 - mae: 0.0338 - val_loss: 0.0061 - val_mae: 0.0514
# Epoch 184/231
# 17/17 - 0s - loss: 0.0024 - mae: 0.0337 - val_loss: 0.0061 - val_mae: 0.0514
# Epoch 185/231
# 17/17 - 0s - loss: 0.0024 - mae: 0.0341 - val_loss: 0.0064 - val_mae: 0.0532
# Epoch 186/231
# 17/17 - 0s - loss: 0.0024 - mae: 0.0343 - val_loss: 0.0064 - val_mae: 0.0534
# Epoch 187/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0346 - val_loss: 0.0065 - val_mae: 0.0538
# Epoch 188/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0346 - val_loss: 0.0065 - val_mae: 0.0535
# Epoch 189/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0348 - val_loss: 0.0066 - val_mae: 0.0553
# Epoch 190/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0350 - val_loss: 0.0068 - val_mae: 0.0563
# Epoch 191/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0354 - val_loss: 0.0067 - val_mae: 0.0558
# Epoch 192/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0351 - val_loss: 0.0068 - val_mae: 0.0558
# Epoch 193/231
# 17/17 - 0s - loss: 0.0025 - mae: 0.0355 - val_loss: 0.0070 - val_mae: 0.0578
# Epoch 194/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0358 - val_loss: 0.0072 - val_mae: 0.0583
# Epoch 195/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0358 - val_loss: 0.0071 - val_mae: 0.0586
# Epoch 196/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0363 - val_loss: 0.0073 - val_mae: 0.0593
# Epoch 197/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0362 - val_loss: 0.0075 - val_mae: 0.0607
# Epoch 198/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0369 - val_loss: 0.0078 - val_mae: 0.0626
# Epoch 199/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0371 - val_loss: 0.0080 - val_mae: 0.0644
# Epoch 200/231
# 17/17 - 0s - loss: 0.0028 - mae: 0.0378 - val_loss: 0.0084 - val_mae: 0.0662
# Epoch 201/231
# 17/17 - 0s - loss: 0.0028 - mae: 0.0381 - val_loss: 0.0086 - val_mae: 0.0679
# Epoch 202/231
# 17/17 - 0s - loss: 0.0029 - mae: 0.0388 - val_loss: 0.0089 - val_mae: 0.0694
# Epoch 203/231
# 17/17 - 0s - loss: 0.0029 - mae: 0.0389 - val_loss: 0.0092 - val_mae: 0.0715
# Epoch 204/231
# 17/17 - 0s - loss: 0.0030 - mae: 0.0397 - val_loss: 0.0099 - val_mae: 0.0753
# Epoch 205/231
# 17/17 - 0s - loss: 0.0031 - mae: 0.0404 - val_loss: 0.0105 - val_mae: 0.0788
# Epoch 206/231
# 17/17 - 0s - loss: 0.0032 - mae: 0.0414 - val_loss: 0.0105 - val_mae: 0.0788
# Epoch 207/231
# 17/17 - 0s - loss: 0.0031 - mae: 0.0407 - val_loss: 0.0102 - val_mae: 0.0774
# Epoch 208/231
# 17/17 - 0s - loss: 0.0031 - mae: 0.0408 - val_loss: 0.0107 - val_mae: 0.0796
# Epoch 209/231
# 17/17 - 0s - loss: 0.0031 - mae: 0.0411 - val_loss: 0.0113 - val_mae: 0.0835
# Epoch 210/231
# 17/17 - 0s - loss: 0.0032 - mae: 0.0421 - val_loss: 0.0117 - val_mae: 0.0854
# Epoch 211/231
# 17/17 - 0s - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0119 - val_mae: 0.0867
# Epoch 212/231
# 17/17 - 0s - loss: 0.0033 - mae: 0.0423 - val_loss: 0.0119 - val_mae: 0.0865
# Epoch 213/231
# 17/17 - 0s - loss: 0.0032 - mae: 0.0421 - val_loss: 0.0116 - val_mae: 0.0850
# Epoch 214/231
# 17/17 - 0s - loss: 0.0032 - mae: 0.0415 - val_loss: 0.0111 - val_mae: 0.0822
# Epoch 215/231
# 17/17 - 0s - loss: 0.0031 - mae: 0.0408 - val_loss: 0.0105 - val_mae: 0.0789
# Epoch 216/231
# 17/17 - 0s - loss: 0.0030 - mae: 0.0398 - val_loss: 0.0100 - val_mae: 0.0758
# Epoch 217/231
# 17/17 - 0s - loss: 0.0029 - mae: 0.0388 - val_loss: 0.0096 - val_mae: 0.0738
# Epoch 218/231
# 17/17 - 0s - loss: 0.0028 - mae: 0.0381 - val_loss: 0.0094 - val_mae: 0.0726
# Epoch 219/231
# 17/17 - 0s - loss: 0.0028 - mae: 0.0376 - val_loss: 0.0092 - val_mae: 0.0720
# Epoch 220/231
# 17/17 - 0s - loss: 0.0028 - mae: 0.0374 - val_loss: 0.0091 - val_mae: 0.0715
# Epoch 221/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0372 - val_loss: 0.0091 - val_mae: 0.0711
# Epoch 222/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0371 - val_loss: 0.0090 - val_mae: 0.0708
# Epoch 223/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0369 - val_loss: 0.0089 - val_mae: 0.0704
# Epoch 224/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0368 - val_loss: 0.0089 - val_mae: 0.0700
# Epoch 225/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0367 - val_loss: 0.0088 - val_mae: 0.0697
# Epoch 226/231
# 17/17 - 0s - loss: 0.0027 - mae: 0.0366 - val_loss: 0.0087 - val_mae: 0.0694
# Epoch 227/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0365 - val_loss: 0.0087 - val_mae: 0.0691
# Epoch 228/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0364 - val_loss: 0.0086 - val_mae: 0.0688
# Epoch 229/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0363 - val_loss: 0.0086 - val_mae: 0.0685
# Epoch 230/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0362 - val_loss: 0.0085 - val_mae: 0.0682
# Epoch 231/231
# 17/17 - 0s - loss: 0.0026 - mae: 0.0361 - val_loss: 0.0085 - val_mae: 0.0680
#
# Loss: 0.85%

# %%
# optimization progress
plot_convergence(search_result)
# Out:
# <AxesSubplot:title={'center':'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %% [markdown]
# The convergence plot shows that the loss function of the GRU model is constant because the firt iteration obtained the lowest lost.

# %%
# best hyper-parameters
print('learning_rate     {}'.format(search_result.x[0]))
print('num_gru_units    {}'.format(search_result.x[1]))
print('num_epochs        {}'.format(search_result.x[2]))
print('num_batch_size    {}'.format(search_result.x[3]))
# Out:
# learning_rate     0.01
# num_gru_units    100
# num_epochs        100
# num_batch_size    100

# %%
print('learning_rate     {}'.format(dimensions[0]))
print('num_gru_units    {}'.format(dimensions[1]))
print('num_epochs        {}'.format(dimensions[2]))
print('num_batch_size    {}'.format(dimensions[3]))
# Out:
# learning_rate     Real(low=0.001, high=1, prior='log-uniform', transform='identity')
# num_gru_units    Integer(low=1, high=500, prior='uniform', transform='identity')
# num_epochs        Integer(low=1, high=500, prior='uniform', transform='identity')
# num_batch_size    Integer(low=1, high=500, prior='uniform', transform='identity')

# %%
search_result.fun
# Out:
# 0.004095755983144045

# %%
sorted(zip(search_result.func_vals, search_result.x_iters))
# Out:
# [(0.004095755983144045, [0.01, 100, 100, 100]),
#  (0.004222552757710218, [0.5678537305011172, 335, 212, 365]),
#  (0.004416720476001501, [0.011213519193128137, 405, 413, 79]),
#  (0.004483707714825869, [0.018974089907460436, 106, 337, 93]),
#  (0.0046703023836016655, [0.0022322453406166676, 405, 45, 203]),
#  (0.004724162630736828, [0.08647870089096632, 247, 500, 217]),
#  (0.004782981239259243, [0.0034277733698657087, 172, 458, 79]),
#  (0.004802332725375891, [0.045253994685277125, 307, 249, 299]),
#  (0.00503504415974021, [0.03837390921709074, 214, 336, 84]),
#  (0.005601651035249233, [0.2618907072295311, 320, 208, 248]),
#  (0.0056054480373859406, [0.12798541829982737, 160, 463, 373]),
#  (0.005707185249775648, [0.028019174068399568, 45, 223, 350]),
#  (0.00587792694568634, [0.001, 308, 291, 144]),
#  (0.006134886294603348, [0.001, 1, 500, 500]),
#  (0.006265360862016678, [0.08059990160335292, 21, 476, 385]),
#  (0.006852647755295038, [0.0033079307746358725, 400, 437, 207]),
#  (0.007252098526805639, [0.010103293074801022, 500, 244, 389]),
#  (0.00787885207682848, [0.001, 463, 113, 439]),
#  (0.00836914498358965, [0.001, 422, 90, 413]),
#  (0.008485822007060051, [0.005065733868873526, 229, 231, 444]),
#  (0.008872074075043201, [0.001, 394, 46, 467]),
#  (0.009677935391664505, [0.001, 1, 245, 462]),
#  (0.011463073082268238, [0.07352450860553598, 415, 1, 322]),
#  (0.011598918586969376, [0.048082590124004565, 117, 1, 212]),
#  (0.022740952670574188, [0.021168464297405504, 439, 1, 365]),
#  (0.030136680230498314, [0.001, 294, 1, 252]),
#  (0.04004441201686859, [1.0, 196, 40, 305]),
#  (0.048539258539676666, [0.001, 327, 1, 500]),
#  (0.08204373717308044, [1.0, 35, 104, 500]),
#  (0.08365949243307114, [1.0, 1, 500, 424]),
#  (0.08720210939645767, [0.9530633332864804, 143, 69, 480]),
#  (0.0981716588139534, [1.0, 486, 259, 50]),
#  (0.11078742891550064, [0.3318649951232258, 434, 348, 110]),
#  (0.11357167363166809, [1.0, 247, 292, 500]),
#  (0.21296246349811554, [0.01566822886115884, 1, 448, 1]),
#  (0.22794251143932343, [0.0856966000169587, 303, 43, 1]),
#  (0.5431800484657288, [0.001, 1, 1, 314]),
#  (0.5961582660675049, [1.0, 500, 500, 2]),
#  (0.8452982306480408, [1.0, 208, 1, 145]),
#  (3.1062774658203125, [1.0, 500, 1, 234])]

# %% [markdown]
# The following figure shows a matrix plot of all combinations of dimensions (hyperparameters). The verticals show the influence of a single dimension on fitness. This is a so-called “Partial Dependence plot” for that dimension. It shows how the approximated fitness value changes with different values in that dimension. The plots below the diagonal show the Partial Dependence for 3 dimensions. This shows how the approximated fitness value changes when we are varying 3 dimensions simultaneously.

# %% [markdown]
# The yellow regions show areas where the loss on the validation set is the lowest as contrary to the darker regions. The star in the plot represents the location where the optimal hyperparameters were found. From the curves shown in the figure below, the loss improves when the GRU model’s learning rate is lower (the model learns better at smaller time steps), its number of GRU units is near 100 or 350 and its number of epochs is bigger near 100 or bigger than 350. The batch size does not seem to affect a lot the loss function.

# %%
_ = plot_objective(result=search_result)

# %% [markdown]
# We also displayed another type of matrix plot: the evaluation plot. Here, the verticals show histograms of the sample distributions for each of the hyperparameters during the Bayesian optimization. The plots below the diagonal show the location of samples in the search space and the color-coding shows the order in which the samples were taken. The early samples are darker while the late samples are yellow. As excepted, the earlier samples were more random and the later samples were more in clusters because a certain pattern started to form, the search was more structured. The hyperparameters were mostly sampled at the limits of the search range. If we had done more iterations, the results would have been even better and the clustering pattern would have been easier to identify.

# %%
_ = plot_evaluations(result=search_result)

# %%
model = load_model(path_best_model)

# %%
result = model.evaluate(x=x_val,
                        y=y_val)
# Out:
# 58/58 [==============================] - 1s 2ms/step - loss: 0.0041 - mae: 0.0443

# %%
for name, value in zip(model.metrics_names, result):
    print(name, value)
# Out:
# loss 0.004085580352693796
# mae 0.044283539056777954

# %%
print("{0}: {1:.2%}".format(model.metrics_names[0], result[0]))
# Out:
# loss: 0.41%

# %% [markdown]
# **Reference:**
#
# Most of the codes from thi notebook was inspired by Magnus Erik Hvass Pedersen work on [Hyper-Parameter Optimization of CNN](https://github.com/Hvass-Labs/TensorFlow-Tutorials/blob/master/19_Hyper-Parameters.ipynb).
